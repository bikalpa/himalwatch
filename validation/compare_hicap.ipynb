# %% [markdown]
# # HimalWatch vs ICIMOD HI-CAP Validation
#
# Computes precision and recall of HimalWatch lake detections against the
# ICIMOD HI-CAP glacial lake inventory (authoritative ground truth).
#
# **TODO**: implement after first full pipeline run produces detections.
#
# Steps:
# 1. Load HI-CAP inventory (request from ICIMOD or use public snapshot)
# 2. Load HimalWatch mart_lake_inventory.parquet
# 3. Spatial join with 50m buffer tolerance
# 4. Compute: TP, FP, FN, precision, recall, F1
# 5. Map false positives (likely snow/shadow) and false negatives (missed lakes)
# 6. Report card for methodology.md
